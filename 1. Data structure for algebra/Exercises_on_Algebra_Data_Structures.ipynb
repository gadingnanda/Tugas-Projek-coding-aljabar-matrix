# %% [markdown]
# Exercises on Algebra Data Structures

# %%
#1.) selesaikan soal berikut
# What is the transpose of this vector
[25 ]
[ 2 ]
[-3 ]
[-25]

# %%
#buat vector dan disimpan sebagai v
import numpy as np
v = np.array([[25],
              [2],
              [-3],
              [-25]])
v
# Out:
# array([[ 25],
#        [  2],
#        [ -3],
#        [-25]])

# %%
#transpose vector v
v_t = v.T
v_t
# Out:
# array([[ 25,   2,  -3, -25]])

# %% [markdown]
# Transpose dari vector
# [25]
# [2]
# [-3]
# [-25]
# adalah
# [25, 2, -3, -25]
