# %% [markdown]
# Scalar

# %%
#buat variabel skalar x dan simpan suatu nilai skalar
x = 66

# %%
#tampilkan tipe data dari x
type(x)
# Out:
# int

# %%
#buat variabel skalar y dan simpan suatu nilai skalar
y = 2515

# %%
#tampilkan tipe data dari y
type(y)
# Out:
# int

# %%
#jumlahkan x+y
x + y
# Out:
# 2581

# %%
#buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 51.5

# %%
#jumlahkan x_float dengan y
x_float + y
# Out:
# 2566.5

# %%
#tampilkan tipe data dari x_float
type(x_float)
# Out:
# float

# %%
#lakukan tahapan pada soal 1 dengan menggunakan tensorflow
import tensorflow as tf

# %%
#buat variabel skalar x dan simpan suatu nilai skalar (Tensor Flow)
x_tf = tf.Variable(66, dtype=tf.float16)

# %%
#tampilkan tipe data dari x (Tensor Flow)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float16, numpy=66.0>

# %%
#buat variabel skalar y dan simpan suatu nilai skalar (Tensor Flow)
y_tf = tf.Variable(2515, dtype=tf.float16)

# %%
#tampilkan tipe data dari y (Tensor Flow)
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float16, numpy=2516.0>

# %%
#jumlahkan x+y (Tensor Flow)
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=float16, numpy=2582.0>

# %%
#buat variabel bernama x_float dan simpan suatu nilai desimal (Tensor Flow)
x_tf_float = tf.Variable(51.5, dtype=tf.float16)

# %%
#jumlahkan x_float dengan y (Tensor Flow)
x_tf_float + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=float16, numpy=2568.0>

# %%
#tampilkan tipe data dari x_float (Tensor Flow)
x_tf_float
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float16, numpy=51.5>

# %%
#lakukan tahapan pada soal 1 dengan menggunakan pytorch
import torch

# %%
#buat variabel skalar x dan simpan suatu nilai skalar (Pytorch)
x_pt = torch.tensor(66, dtype=torch.int16)

# %%
#tampilkan tipe data dari x (Pytorch)
x_pt
# Out:
# tensor(66, dtype=torch.int16)

# %%
#buat variabel skalar y dan simpan suatu nilai skalar (Pytorch)
y_pt = torch.tensor(2515, dtype=torch.int16)

# %%
#tampilkan tipe data dari y (Pytorch)
y_pt
# Out:
# tensor(2515, dtype=torch.int16)

# %%
#jumlahkan x+y (Pytorch)
x_pt + y_pt
# Out:
# tensor(2581, dtype=torch.int16)

# %%
#buat variabel bernama x_float dan simpan suatu nilai desimal (Pytorch)
x_pt_float = torch.tensor(51.5, dtype=torch.float16)

# %%
#jumlahkan x_float dengan y (Pytorch)
x_pt_float + y_pt
# Out:
# tensor(2568., dtype=torch.float16)

# %%
#tampilkan tipe data dari x_float (Pytorch)
x_pt_float
# Out:
# tensor(51.5000, dtype=torch.float16)
